# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
delta = pd.read_csv('delta.csv')
delta
# Out:
#       stateDt   susceptible     infected      recovered         died
# 0    20200301  4.999626e+07  3688.000000      30.000000    18.000000
# 1    20200302  4.999579e+07  4159.000000      31.000000    22.000000
# 2    20200303  4.999519e+07  4750.000000      34.000000    28.000000
# 3    20200304  4.999467e+07  5255.000000      41.000000    32.000000
# 4    20200305  4.999423e+07  5643.000000      88.000000    35.000000
# ..        ...           ...          ...            ...          ...
# 512  20210727  4.987917e+07   137.275576  118881.914210  1957.500159
# 513  20210728  4.987917e+07   131.542792  118891.111673  1957.607305
# 514  20210729  4.987917e+07   126.049415  118899.925040  1957.709976
# 515  20210730  4.987916e+07   120.785447  118908.370351  1957.808359
# 516  20210731  4.987916e+07   115.741309  118916.462976  1957.902634
#
# [517 rows x 5 columns]

# %%
plt.plot(delta.died)
plt.legend(['Died'])
plt.show()

# %%
plt.plot(delta.susceptible)
plt.legend(['susceptible'])
plt.show()

plt.plot(delta.infected)
plt.legend(['infected'])
plt.show()

plt.plot(delta.recovered)
plt.legend(['recovered'])
plt.show()
