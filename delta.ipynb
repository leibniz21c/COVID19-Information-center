# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
delta = pd.read_csv('delta.csv')
delta
# Out:
#       stateDt  susceptible        exposed       infected      recovered  \
# 0    20200301     0.999258   6.672000e-04   7.376000e-05   6.000000e-07
# 1    20200302     0.999240   6.759800e-04   8.318000e-05   6.200000e-07
# 2    20200303     0.999193   7.111000e-04   9.500000e-05   6.800000e-07
# 3    20200304     0.999325   5.682800e-04   1.051000e-04   8.200000e-07
# 4    20200305     0.999448   4.362000e-04   1.128600e-04   1.760000e-06
# ..        ...          ...            ...            ...            ...
# 442  20210772     1.000000  3.567418e-204  3.294840e-204  1.945634e-203
# 443  20210799     1.000000  6.944813e-212  6.504913e-212  3.935419e-211
# 444  20210827     1.000000  1.352429e-219  1.283265e-219  7.958003e-219
# 445  20210856     1.000000  2.634549e-227  2.529815e-227  1.608796e-226
# 446  20210886     1.000000  5.133651e-235  4.984090e-235  3.251492e-234
#
#               died    deltaS    deltaE    deltaI         delta  Unnamed: 10
# ...

# %%
plt.plot(delta.died)
plt.legend(['Died'])
plt.show()

# %%
plt.plot(delta.susceptible)
plt.legend(['susceptible'])
plt.show()

plt.plot(delta.exposed)
plt.legend(['exposed'])
plt.show()

plt.plot(delta.infected)
plt.legend(['infected'])
plt.show()

plt.plot(delta.recovered)
plt.legend(['recovered'])
plt.show()

# %%
plt.plot(delta.deltaS)
plt.legend(['deltaS'])
plt.show()

plt.plot(delta.deltaE)
plt.legend(['deltaE'])
plt.show()

plt.plot(delta.deltaI)
plt.legend(['deltaI'])
plt.show()

plt.plot(delta.deltaR)
plt.legend(['deltaR'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-f3d30ab2637d> in <module>
#      11 plt.show()
#      12
# ---> 13 plt.plot(delta.deltaR)
#      14 plt.legend(['deltaR'])
#      15 plt.show()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'deltaR'
